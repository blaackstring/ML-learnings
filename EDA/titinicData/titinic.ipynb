# %%
import pandas as pd
import seaborn as sns
import numpy as np
test_data=pd.read_csv('./test.csv')
train_data=pd.read_csv('./train.csv')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#CATEGIRCAL COLUMNS

train_data['Sex'].unique()
#array(['male', 'female'], dtype=object)

train_data['Embarked'].unique()
#array(['S', 'C', 'Q', nan], dtype=object)

train_data['SibSp'].unique()
#array([1, 0, 3, 4, 2, 5, 8])

train_data['Parch'].unique()
#array([0, 1, 2, 5, 3, 4, 6])

train_data['Pclass'].unique()
#array([3, 1, 2])
train_data['Survived'].unique()  # //target 
#array([0, 1])
# Out:
# array([0, 1])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#NUMERIAL COUMNS
#Column Types

# • Numerical - Age, Fare, PassengerId

# • Categorical - Survived, Pclass, Sex, SibSp, Parch, Embarked

# • Mixed - Name, Ticket, Cabin
train_data['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
#START from AGE column

# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(train_data['Age'])
plt.show()

# %%
train_data['Age'].plot(kind='kde')
train_data['Age'].skew()

#age is some skewed postiove
# Out:
# np.float64(0.38910778230082704)

# %%
plt.scatter(train_data['Age'],train_data['Fare'],c=train_data['Survived']==1)

# %%
female_dead = train_data[
    (train_data['Sex'] == 'female') &
    (train_data['Survived'] == 0)
]

plt.hist(female_dead['Age'].dropna(), bins=10)
plt.xlabel("Age")
plt.ylabel("Number of Females")
plt.title("Age Distribution of Females Who Died")
plt.show()

# %%
len(train_data[(train_data['Age'] > 50) & (train_data['Sex']=='female')]) / len(train_data['Age']) * 100
# Out:
# 1.9079685746352413

# %%
train_data['Fare'].plot(kind='kde')
train_data['Fare'].skew()
# Out:
# np.float64(4.787316519674893)

# %%
train_data[train_data['Sex']=='male']['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
train_data[train_data['Sex']=='male']['Survived'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
train_data['Survived'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
data=train_data[(train_data['Embarked']=='C')& (train_data['Survived']==0)]['Survived'].value_counts()/len(
    train_data[train_data['Survived'] == 0]
)
data*100
#77 % people are from S who died
# 8.5 % people are from Q who died
# Out:
# Survived
# 0    13.661202
# Name: count, dtype: float64
