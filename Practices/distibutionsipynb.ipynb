# %% [markdown]
# <a href="https://colab.research.google.com/github/blaackstring/ML-learnings/blob/main/distibutionsipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("yasserh/student-marks-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 949/949 [00:00<00:00, 1.68MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/yasserh/student-marks-dataset/versions/1

# %%
import pandas as pd
df=pd.read_csv(path+"/Student_Marks.csv")

df.sample(50)
# Out:
#     number_courses  time_study   Marks
# 26               7       0.508  12.647
# 52               4       0.771   7.892
# 25               3       1.407   6.623
# 4                8       7.811  55.299
# 9                3       6.173  30.862
# 37               6       7.283  46.453
# 16               5       5.719  30.548
# 40               4       0.140   7.336
# 61               4       2.438  10.844
# 49               5       3.913  19.106
# 10               3       7.353  42.036
# 5                6       3.211  17.822
# 69               6       3.948  21.400
# 0                3       4.508  19.202
# 60               6       0.376  10.522
# 41               6       2.754  15.725
# 51               6       4.130  22.184
# 96               3       0.301   5.609
# 66               4       5.473  27.569
# 81               8       2.262  17.705
# 74               4       6.954  39.952
# 88               5       1.803  11.253
# 19               8       3.977  25.133
# ...

# %%
df['time_study'].max()
# Out:
# 7.957

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.describe()
# Out:
#        number_courses  time_study       Marks
# count      100.000000  100.000000  100.000000
# mean         5.290000    4.077140   24.417690
# std          1.799523    2.372914   14.326199
# min          3.000000    0.096000    5.609000
# 25%          4.000000    2.058500   12.633000
# 50%          5.000000    4.022000   20.059500
# 75%          7.000000    6.179250   36.676250
# max          8.000000    7.957000   55.299000

# %%
df['number_courses'].isnull().sum()
# Out:
# np.int64(0)

# %%
df_mean=df.mean()
df_median=df.median()
df_mode=df.mode()

# print(df_mean)
# print("----------------------------------------------------------")
# print(df_median)
# print("----------------------------------------------------------")
print(df_mode)
# Out:
#     number_courses  time_study   Marks
# 0              3.0       0.096   5.609
# 1              NaN       0.130   6.053
# 2              NaN       0.140   6.185
# 3              NaN       0.156   6.217
# 4              NaN       0.301   6.349
# ..             ...         ...     ...
# 95             NaN       7.711  53.018
# 96             NaN       7.775  53.158
# 97             NaN       7.811  53.359
# 98             NaN       7.909  54.321
# 99             NaN       7.957  55.299
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.hist(df['number_courses'])
plt.title('Courses')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df[['Marks']])
plt.title('Marks')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.hist(df[['time_study']],bins=40)
plt.title('Marks')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Marks'], kde=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(df['Marks'], kde=True)
plt.show()

# %%
import numpy as np

log_marks=np.log(df['Marks'])

n
sns.displot(log_marks, kde=True)

# %%
df['Marks'].skew()
# Out:
# np.float64(0.6582365955082408)
