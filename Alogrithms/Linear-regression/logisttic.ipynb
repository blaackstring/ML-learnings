# %%
from kagglehub import KaggleDatasetAdapter
import kagglehub
from dotenv import load_dotenv

# Note the correct file name here
file_path = "disease_prediction.csv"
load_dotenv()

# load_dataset is deprecated, but you can still use it or switch to kagglehub.dataset_load
df = kagglehub.dataset_load(
    KaggleDatasetAdapter.PANDAS,
    "shyamnadhs/heart-disease-prediction-dataset",
    file_path,
)

# Test it
df.head()
# Out:
#    patient_id  age  gender  glucose_mg_dl  cholesterol_mg_dl  systolic_bp  \
# 0           1   32    Male            101                235          152
# 1           2   31    Male            124                191          134
# 2           3   45    Male             57                141          114
# 3           4   75  Female             69                268          120
# 4           5   53    Male            107                163          131
#
#    diastolic_bp   bmi  heart_rate smoking alcohol_consumption  \
# 0            79  28.5          73      No                 Yes
# 1            77  33.9          71      No                 Yes
# 2            71  27.2          79     Yes                 Yes
# 3            82  21.5          61     Yes                 Yes
# 4            75  23.3          73     Yes                  No
#
#   physical_activity family_history disease
# 0               Low            Yes     Yes
# 1               Low            Yes     Yes
# ...

# %%
df.sample(5)
# Out:
#      patient_id  age  gender  glucose_mg_dl  cholesterol_mg_dl  systolic_bp  \
# 643         644   50    Male            100                191          110
# 153         154   59    Male            109                252          106
# 888         889   57  Female             61                188          120
# 445         446   75    Male            119                220          115
# 974         975   55    Male             91                327          107
#
#      diastolic_bp   bmi  heart_rate smoking alcohol_consumption  \
# 643            81  22.4          73     Yes                  No
# 153            83  23.8          68      No                  No
# 888            84  28.4          87      No                 Yes
# 445            71  22.5          56     Yes                  No
# 974            72  29.6          70     Yes                 Yes
#
#     physical_activity family_history disease
# 643              High            Yes      No
# ...

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         patient_id          age  glucose_mg_dl  cholesterol_mg_dl  \
# count  1000.000000  1000.000000    1000.000000        1000.000000
# mean    500.500000    51.190000     104.163000         210.014000
# std     288.819436    19.847514      25.076508          39.749111
# min       1.000000    18.000000      30.000000          89.000000
# 25%     250.750000    33.000000      87.000000         183.000000
# 50%     500.500000    52.500000     105.000000         210.500000
# 75%     750.250000    69.000000     121.000000         235.250000
# max    1000.000000    85.000000     184.000000         339.000000
#
#        systolic_bp  diastolic_bp          bmi   heart_rate
# count  1000.000000   1000.000000  1000.000000  1000.000000
# mean    123.893000     81.032000    26.093000    75.968000
# std      18.701211      9.969974     4.758282     9.902982
# min      67.000000     49.000000    16.000000    47.000000
# 25%     111.000000     74.000000    22.900000    70.000000
# ...

# %%
df.nunique()
# Out:
# patient_id             1000
# age                      68
# gender                    2
# glucose_mg_dl           131
# cholesterol_mg_dl       188
# systolic_bp              94
# diastolic_bp             56
# bmi                     206
# heart_rate               58
# smoking                   2
# alcohol_consumption       2
# physical_activity         3
# family_history            2
# disease                   2
# dtype: int64

# %%
df["disease"].value_counts()
# Out:
# disease
# Yes    501
# No     499
# Name: count, dtype: int64

# %%
#make a graph of diease with bmi
import matplotlib.pyplot as plt
x=df["age"]
y=df["heart_rate"]
plt.scatter(x, y,c=df["disease"].map({
    "Yes": "red",
    "No": "blue"
}))
plt.xlabel("Age")
plt.ylabel("BMI")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 2
#       1 #make a graph of diease with bmi
# ----> 2 import matplotlib.pyplot as plt
#       3 x=df["age"]
#       4 y=df["heart_rate"]
#       5 plt.scatter(x, y,c=df["disease"].map({
#
# File c:\Users\siddi\OneDrive\Desktop\MACHINE LEARNING\.venv\Lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File c:\Users\siddi\OneDrive\Desktop\MACHINE LEARNING\.venv\Lib\site-packages\matplotlib\rcsetup.py:26
#      23 import numpy as np
# ...

# %%
age = df[(df["age"] >= 55) & (df["age"] <= 80)]

print(age["disease"].value_counts())

#In this dataset, individuals aged 55–80 have a higher proportion of disease cases.
# Out:
# disease
# Yes    261
# No     144
# Name: count, dtype: int64

# %%
df['age']
# Out:
# 0      32
# 1      31
# 2      45
# 3      75
# 4      53
#        ..
# 995    24
# 996    40
# 997    44
# 998    31
# 999    83
# Name: age, Length: 1000, dtype: int64

# %%
df
# Out:
#      patient_id  age  gender  glucose_mg_dl  cholesterol_mg_dl  systolic_bp  \
# 0             1   32    Male            101                235          152
# 1             2   31    Male            124                191          134
# 2             3   45    Male             57                141          114
# 3             4   75  Female             69                268          120
# 4             5   53    Male            107                163          131
# ..          ...  ...     ...            ...                ...          ...
# 995         996   24    Male            105                237           86
# 996         997   40    Male            120                219          133
# 997         998   44  Female            114                273          114
# 998         999   31    Male             95                231          130
# 999        1000   83    Male            109                256          103
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  LogisticRegression
from sklearn.preprocessing import  LabelEncoder

le=LabelEncoder()



x = df[['age', 'heart_rate']]
y=df['disease']


x_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)


model = LogisticRegression()
model.fit(x_train,y_train)

model.predict([[53, 70]])
# Out:
# c:\Users\siddi\OneDrive\Desktop\MACHINE LEARNING\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:456: OptimizeWarning: Unknown solver options: iprint
#   opt_res = optimize.minimize(
# c:\Users\siddi\OneDrive\Desktop\MACHINE LEARNING\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Yes'], dtype=object)
